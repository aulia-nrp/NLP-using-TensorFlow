# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# **Dataset**
#
# We gather the data for the dataset by scraping Twitter's tweet that contain words about incidents of sexual violence and harassment from the victim. We scrap #MeToo hashtag which is a social movement against sexual abuse and sexual harassment where people publicize allegations of sex crimes. The phrase "Me Too" was initially used in this context on social media in 2006, on Myspace, by sexual harassment survivor and activist Tarana Burke.

# %% [markdown]
# We collected the data with 7 period time.
#
#
# 1.   1st period: 15 April - 23 April 2021
# 2.   2nd period: 23 April - 29 April 2021
# 3.   3rd period: 29 April - 05 May 2021
# 4.   4th period: 05 May - 11 May 2021
# 5.   5th period: 11 May - 17 May 2021
# 6.   6th period: 17 May - 23 May 2021
# 7.   7th period: 23 May - 29 May 2021
#
# To reduce overfitting, we manually added some additional data as mentioned below.

# %% [markdown]
# # Import

# %%
#Imports
import pandas as pd
import numpy as np
import re
import pandas_profiling

# %%
pip install -U pandas-profiling
# Out:
# Requirement already up-to-date: pandas-profiling in /usr/local/lib/python3.7/dist-packages (3.0.0)
# ...

# %% [markdown]
# # 1st period (15 Apr - 23 Apr 2021)

# %%
#Import First Dataset
url_one = 'https://drive.google.com/file/d/1lTvQke_pO35JgAj1Bzj5ULsA_gno94DQ/view?usp=sharing'
file_id_one = url_one.split('/')[-2]
csv_url_one = 'https://drive.google.com/uc?id=' + file_id_one
df_one = pd.read_csv(csv_url_one)
df_one.head()
# Out:
#    index  ...                                               text
# 0      1  ...  b\'"The ironies of the #MeToo movement are too...
# 1      2  ...  RT @WomenReadWomen: Women in Kuwait have launc...
# 2      3  ...  RT @j_andreamolina: \\xe2\\x9a\\xa0\\xef\\xb8\...
# 3      4  ...  RT @SammiStitches: Charges brought against the...
# 4      5  ...  b"And the fourth presenter on 26th May is Hann...
#
# [5 rows x 4 columns]

# %%
print("Shape of 1st period data-> ", df_one.shape)
# Out:
# Shape of 1st period data->  (6600, 4)

# %% [markdown]
# # 2nd period (23 Apr - 29 Apr 2021)

# %%
#Import Second Dataset
url_two = 'https://drive.google.com/file/d/1xMEtidbapgBLs82ijoJvk0FsoPlL76yG/view?usp=sharing'
file_id_two = url_two.split('/')[-2]
csv_url_two = 'https://drive.google.com/uc?id=' + file_id_two
df_two = pd.read_csv(csv_url_two)
df_two.head()
# Out:
#    index  ...                                               text
# 0      1  ...  b\'RT @ThatUmbrella: Advocates of #metoo shoul...
# 1      2  ...  Boo another report while casualties pile up! Y...
# 2      3  ...  b"RT @MsAmyMacPherson: 1/9 There\'s a SUPER HU...
# 3      4  ...  b"RT @RaquelDancho: Important to note: if the ...
# 4      5  ...  RT @Aspasia_1: Basically .@MetOpera could have...
#
# [5 rows x 4 columns]

# %%
print("Shape of 2nd period data-> ", df_two.shape)
# Out:
# Shape of 2nd period data->  (8900, 4)

# %% [markdown]
# # 3rd period (29 Apr - 05 May 2021)

# %%
#Import Third Dataset
url_three = 'https://drive.google.com/file/d/1vNVBMchza3792vB16pGQwzHf65eJYlOB/view?usp=sharing'
file_id_three = url_three.split('/')[-2]
csv_url_three = 'https://drive.google.com/uc?id=' + file_id_three
df_three = pd.read_csv(csv_url_three)
df_three.head()
# Out:
#    index  ...                                               text
# 0      1  ...  RT @BombshellDAILY: REPUBLICAN BRUTALLY RAPES ...
# 1      2  ...  b"Anthony Kiedis mocked those fighting Bin Lad...
# 2      3  ...  RT @edrormba: Palestinian-American brings #MeT...
# 3      4  ...  RT @bette_oh: And, just like that, the #MeToo ...
# 4      5  ...  This guy was in #MeToo right?? https://t.co/zZ...
#
# [5 rows x 4 columns]

# %%
print("Shape of 3rd period data-> ", df_three.shape)
# Out:
# Shape of 3rd period data->  (7100, 4)

# %% [markdown]
# # 4th period (05 May - 11 May 2021)

# %%
#Import Fourth Dataset
url_four = 'https://drive.google.com/file/d/1vb98LLK4QPEzb5_jB0q19O1xU6WF3vgh/view?usp=sharing'
file_id_four = url_four.split('/')[-2]
csv_url_four = 'https://drive.google.com/uc?id=' + file_id_four
df_four = pd.read_csv(csv_url_four)
df_four.head()
# Out:
#    index  ...                                               text
# 0      1  ...  RT @SVPAOfficial: As the movement continues to...
# 1      2  ...  Sound like #SameGirl cuz #MeToo nigga \\xf0\\x...
# 2      3  ...  RT @mommamia1217: B\\xf0\\x9f\\x94\\xa5\\xf0\\...
# 3      4  ...  RT @mommamia1217: B\\xf0\\x9f\\x94\\xa5\\xf0\\...
# 4      5  ...  RT @mommamia1217: B\\xf0\\x9f\\x94\\xa5\\xf0\\...
#
# [5 rows x 4 columns]

# %%
print("Shape of 4th period data-> ", df_four.shape)
# Out:
# Shape of 4th period data->  (7650, 4)

# %% [markdown]
# # 5th period (11 May - 17 May 2021)

# %%
#Import Fifth Dataset
url_five = 'https://drive.google.com/file/d/1HpNQ-YktcMS1lckdHJKyAGIoChWjaxhX/view?usp=sharing'
file_id_five = url_five.split('/')[-2]
csv_url_five = 'https://drive.google.com/uc?id=' + file_id_five
df_five = pd.read_csv(csv_url_five)
df_five.head()
# Out:
#    index  ...                                               text
# 0      1  ...  RT @gbrockell: I first contacted Barbara in De...
# 1      2  ...  RT @ShefVaidya: This is Vinod Dua for you, the...
# 2      3  ...  RT @ShefVaidya: This is Vinod Dua for you, the...
# 3      4  ...  5.2 million Americans are living with #PTSD. \...
# 4      5  ...  b"RT @ghazalimohammad: First MLA Pargat Singh ...
#
# [5 rows x 4 columns]

# %%
print("Shape of 5th period data-> ", df_five.shape)
# Out:
# Shape of 5th period data->  (7700, 4)

# %% [markdown]
# # 6th period (17 May - 23 May 2021)

# %%
#Import Sixth Dataset
url_six = 'https://drive.google.com/file/d/16zIaxx9ua0hThr23x4N_cNhUymgsPBqC/view?usp=sharing'
file_id_six = url_six.split('/')[-2]
csv_url_six = 'https://drive.google.com/uc?id=' + file_id_six
df_six = pd.read_csv(csv_url_six)
df_six.head()
# Out:
#    index  ...                                               text
# 0      1  ...  b"8:43 PM a while ago  I went to this store ne...
# 1      2  ...  @theserfstv Ross bought $DOGE early and thinks...
# 2      3  ...  John 1 Reading of Final Verses + Emergency Pra...
# 3      4  ...  b"RT @Terrn1981: @jackappleby @Girlguiding Opp...
# 4      5  ...  John 1 Reading of Final Verses + Emergency Pra...
#
# [5 rows x 4 columns]

# %%
print("Shape of 6th period data-> ", df_six.shape)
# Out:
# Shape of 6th period data->  (8600, 4)

# %% [markdown]
# # 7th period (23 May - 29 May 2021)

# %%
#Import Sixth Dataset
url_seven = 'https://drive.google.com/file/d/1MKzXuUYI1-kOMWA9QPxnFPUIrGqjdHLw/view?usp=sharing'
file_id_seven = url_seven.split('/')[-2]
csv_url_seven = 'https://drive.google.com/uc?id=' + file_id_seven
df_seven = pd.read_csv(csv_url_seven)
df_seven.head()
# Out:
#    index  ...                                               text
# 0      1  ...  b"\'\\xf0\\x9d\\x97\\x9c \\xf0\\x9d\\x98\\x81\...
# 1      2  ...  RT @pachchakkili: #Thread on how the other 201...
# 2      3  ...  b\'RT @BlackVotersMtr: "In the five years sinc...
# 3      4  ...  b\'RT @BlackVotersMtr: "In the five years sinc...
# 4      5  ...  . @smitha_tk discussed the #MeToo movement and...
#
# [5 rows x 4 columns]

# %%
print("Shape of 7th period data-> ", df_seven.shape)
# Out:
# Shape of 7th period data->  (12050, 4)

# %% [markdown]
# # Combine All Dataset

# %% [markdown]
# After we collected all data within time period, we combined it into a new dataframe. There are 4 columns:
#
# 1.   'index' : index of tweets
# 2.   'user_id' : user ID that make the tweet
# 3.   'timestamp' : time when the user tweet
# 4.   'text' : tweets

# %%
df_all = pd.concat([df_one, df_two, df_three, df_four, df_five, df_six, df_seven])

# %%
df_all.head()
# Out:
#    index  ...                                               text
# 0      1  ...  b\'"The ironies of the #MeToo movement are too...
# 1      2  ...  RT @WomenReadWomen: Women in Kuwait have launc...
# 2      3  ...  RT @j_andreamolina: \\xe2\\x9a\\xa0\\xef\\xb8\...
# 3      4  ...  RT @SammiStitches: Charges brought against the...
# 4      5  ...  b"And the fourth presenter on 26th May is Hann...
#
# [5 rows x 4 columns]

# %%
print("Combined shape of all data-> ", df_all.shape)
# Out:
# Combined shape of all data->  (58600, 4)

# %% [markdown]
# Shape of each period data:
#
#
# 1.   1st period : 6600
# 2.   2nd period : 8900
# 3.   3rd period : 7100
# 4.   4th period : 7650
# 5.   5th period : 7700
# 6.   6th period : 8600
# 7.   7th period : 12050
#
# **TOTAL: 58600 tweets**

# %%
# Check null
df_all.isnull().sum()
# Out:
# index        0
# user_id      0
# timestamp    0
# text         0
# dtype: int64

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58600 entries, 0 to 12049
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      58600 non-null  int64
#  1   user_id    58600 non-null  object
#  2   timestamp  58600 non-null  object
#  3   text       58600 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.2+ MB

# %%
df_all.profile_report()

# %% [markdown]
# # Data Cleaning
#
#
# *   Drop unecessary columns
# *   Cleaning with regular expression (clean new line command, 'b', retweet, unicode, non-alphabetic character, extra space, and adding space after slash)
#
#
# *   Transform into lowercase
# *   Drop duplicate
#
# *   Fill & drop empty cells
#
# *   Creating word count
# *   Creating word cloud

# %% [markdown]
# # Initial Dataset Cleaning

# %% [markdown]
# We will use 'text' column to get the tweet because our analysis and project will be based on this column.

# %%
# Drop unecessary columns
df = df_all.drop(columns=['index', 'user_id', 'timestamp'])

# %% [markdown]
# Here we can see for some tweets that there are still many contractions like 'RT', user ID, URL, and punctuations.

# %%
for index,text in enumerate(df['text'][50:60]):
  print('Tweets %d:\n'%(index+1),text)
# Out:
# Tweets 1:
#  RT @SammiStitches: Charges brought against the guy that smacked my ass: sexual assault and battery. Fuck around and find out. \\xf0\\x9f\\x91\\x8a#sexualAssau\\xe2\\x80\\xa6'
# Tweets 2:
#  RT @SammiStitches: Charges brought against the guy that smacked my ass: sexual assault and battery. Fuck around and find out. \\xf0\\x9f\\x91\\x8a#sexualAssau\\xe2\\x80\\xa6'
# Tweets 3:
#  RT @KellyPlu: Harassment, retaliation &amp
# Tweets 4:
#  Looking forward 2 a panel chat @CityCynthia today about systemic violence of police women in Canada. I am grateful the team of women on the panel &amp
# Tweets 5:
#  @ArunKrishnan_ This b...d is in #MeToo case, does not talk about it.'
# Tweets 6:
#  This is the child that was born as a result of a statutory rape committed by NLRPD cop Tommy Norman. The mother was 15 when Officer Norman had sex with her and got her pregnant. NLRPD needs to address
# Tweets 7:
#  RT @GIWLkings: EVENT: A new cultural reckoning? Gendered violence &amp
# ...

# %%
#Safe Clean (Cleaning the new line command before it get removed by the next regex)
df['text'] =  [re.sub(r"\\n", " ", str(j)) for j in df['text']]

#Cleaning the 'b', Retweet, Mentions, Unicode (\x08\,\xef\,etc), and puctuation marks.
df['text'] =  [re.sub(r"^b|http\S+|[0-9]\/[0-9]|\'|\"|\:|\;|\+|\.|\,|RT|\\\\x[\w][\w]|\@[\w\_]*|\#[\w]*|\\", "", str(j)) for j in df['text']]

#Clean other punctuation that remains and digits
df['text'] =  [re.sub(r"|\=|\-|\#[\w]*\s?|[a-z]*\#[\w]*\s?|[\(\)\|\!\$\?\*\+\[\]\{\}\%]*|\&amp|[0-9]*", "", str(j)) for j in df['text']]

#Clean extra space in the beginning, middle, and last of the sentence
df['text'] = df['text'].apply(lambda x: x.strip()).apply(lambda x: " ".join(x.split()))

#Adding space after slash
df['text'] =  [re.sub(r"\/", " ", str(j)) for j in df['text']]
df.head()
# Out:
#                                                 text
# 0  The ironies of the movement are too painfully ...
# 1  Women in Kuwait have launched a social media c...
# 2  Triger Warning Raising Awareness of Sexual Ass...
# 3  Charges brought against the guy that smacked m...
# 4  And the fourth presenter on th May is Hannah B...

# %%
#Transform the text into lowercase
df['text'] = df['text'].str.lower()

# %%
#Drop any duplicate row
df = df.drop_duplicates()

# %%
#Fill up the empty cells
df['text'].replace('', np.nan, inplace=True)

# %%
#Drop empty cells
df.dropna(subset=['text'], inplace=True)

# %% [markdown]
# As we can see now, all the constractions already removed and the text already transformed into lowercase text.

# %%
for index,text in enumerate(df['text'][50:60]):
  print('Tweets %d:\n'%(index+1),text)
# Out:
# Tweets 1:
#  just one question where is english teacher marka bodine sexually abused boy under for three years unt
# Tweets 2:
#  these ladies have been facing sexual harassment and brutally tortured during interrogation
# Tweets 3:
#  where tf is high school teacher monica young admitted to repeatedly sexually assaulting a yearold hi
# Tweets 4:
#  starship sara grunt records on youtube
# Tweets 5:
#  the movement including the brave women who have gone to court and the debut of the civil code have reinvigora
# Tweets 6:
#  he also had this app on his phones its used to hide messages within jpg images
# Tweets 7:
#  the movement including the brave women who have gone to court and the debut of the civil code have reinvigorated discussions about sexual harassment in china
# Tweets 8:
#  actually amazing to see standing up to be counted with the and decolonisation sessions massive respect to the speakers who have given us a lot to think about time to decolonise
# Tweets 9:
# ...

# %%
#Create Index
df['index'] = range(0, len(df.index), 1)
df.head()
# Out:
#                                                 text  index
# 0  the ironies of the movement are too painfully ...      0
# 1  women in kuwait have launched a social media c...      1
# 2  triger warning raising awareness of sexual ass...      2
# 3  charges brought against the guy that smacked m...      3
# 4  and the fourth presenter on th may is hannah b...      4

# %%
df.profile_report()

# %%
# Creating the word count column
df['word_count'] = df['text'].apply(lambda x: len(str(x).split()))
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                 text  index  word_count
# 0  the ironies of the movement are too painfully ...      0          31
# 1  women in kuwait have launched a social media c...      1          18
# 2  triger warning raising awareness of sexual ass...      2          11
# 3  charges brought against the guy that smacked m...      3          18
# 4  and the fourth presenter on th may is hannah b...      4          32

# %%
# Shape of cleaned data
print("Shape of cleaned data-> ", df.shape)
# Out:
# Shape of cleaned data->  (19455, 2)

# %%
#Save DataFrame to CSV
df.to_csv("capstoneinitialtweetcleaned.csv", index=False)

# %%
df.profile_report()

# %% [markdown]
# # Word Cloud of Initial Dataset

# %%
#Tokenize Words
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

#df['text'] = df['text'].apply(lambda x: word_tokenize(x))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df_word_cloud = pd.DataFrame()
df_word_cloud['index'] = df['index']
df_word_cloud['text'] = df['text']

# %%
df_word_cloud['text'] = df['text'].apply(lambda x: word_tokenize(x))

# %%
df_word_cloud['text']
# Out:
# 0        [the, ironies, of, the, movement, are, too, pa...
# 1        [women, in, kuwait, have, launched, a, social,...
# 2        [triger, warning, raising, awareness, of, sexu...
# 3        [charges, brought, against, the, guy, that, sm...
# 4        [and, the, fourth, presenter, on, th, may, is,...
#                                ...
# 19450                               [specially, case, and]
# 19451    [the, woman, who, drafted, my, letter, of, pro...
# 19452    [the, listing, on, bookmad, under, spotlight, ...
# 19453    [theyre, trying, to, do, pr, for, him, on, us,...
# 19454    [i, sometimes, wonder, if, i, knew, who, my, r...
# Name: text, Length: 19455, dtype: object

# %%
#Remove Stopwords in Texts

nltk.download('stopwords')
from nltk.corpus import stopwords
list_stopwords = stopwords.words('english')

def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df_word_cloud['text'] = df_word_cloud['text'].apply(stopwords_removal)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_word_cloud['text']
# Out:
# 0        [ironies, movement, painfully, obvious, spearh...
# 1        [women, kuwait, launched, social, media, campa...
# 2        [triger, warning, raising, awareness, sexual, ...
# 3        [charges, brought, guy, smacked, ass, sexual, ...
# 4        [fourth, presenter, th, may, hannah, baylor, p...
#                                ...
# 19450                                    [specially, case]
# 19451    [woman, drafted, letter, protection, protect, ...
# 19452    [listing, bookmad, spotlight, book, burning, d...
# 19453    [theyre, trying, pr, us, victims, sexual, misc...
# 19454    [sometimes, wonder, knew, rapist, person, even...
# Name: text, Length: 19455, dtype: object

# %%
#Lemmatizing the Texts
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
  
lemmatizer = WordNetLemmatizer()

def lemmatize(words):
  return [lemmatizer.lemmatize(word) for word in words]

df_word_cloud['text'] = df_word_cloud['text'].apply(lemmatize)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df_word_cloud['text']
# Out:
# 0        [irony, movement, painfully, obvious, spearhea...
# 1        [woman, kuwait, launched, social, medium, camp...
# 2        [triger, warning, raising, awareness, sexual, ...
# 3        [charge, brought, guy, smacked, as, sexual, as...
# 4        [fourth, presenter, th, may, hannah, baylor, p...
#                                ...
# 19450                                    [specially, case]
# 19451    [woman, drafted, letter, protection, protect, ...
# 19452    [listing, bookmad, spotlight, book, burning, d...
# 19453    [theyre, trying, pr, u, victim, sexual, miscon...
# 19454    [sometimes, wonder, knew, rapist, person, even...
# Name: text, Length: 19455, dtype: object

# %%
df_word_cloud.head()
# Out:
#    index                                               text
# 0      0  [irony, movement, painfully, obvious, spearhea...
# 1      1  [woman, kuwait, launched, social, medium, camp...
# 2      2  [triger, warning, raising, awareness, sexual, ...
# 3      3  [charge, brought, guy, smacked, as, sexual, as...
# 4      4  [fourth, presenter, th, may, hannah, baylor, p...

# %%
from wordcloud import WordCloud

cloud = WordCloud(width=1600, height=800)
text = cloud.generate(df_word_cloud['text'].to_string())

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10), facecolor='k')
plt.imshow(text)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
plt.savefig('wordcloud_initial.png', facecolor='k',bbox_inches='tight')

# %% [markdown]
# # Additional Dataset

# %% [markdown]
# We used our dataset for 2 classification, which is for post classification and report classification.
#
#
# *   For post classification there are 6 classes:
#
#
# 1.   'Siber'
# 2.   'Lokasi Pendidikan'
# 3.   'Lokasi Kerja'
# 4.   'Lokasi Privat'
# 5.   'Lokasi Publik'
# 6.   'Netral'
#
#
# *   For report classification there are 7 classes:
#
#
# 1.   'Eksploitasi'
# 2.   'Eksploitasi Seksual'
# 3.   'Penelantaran'
# 4.   'Kekerasan Psikis'
# 5.   'Kekerasan Fisik'
# 6.   'Kekerasan Seksual'
# 7.   'Kekerasan Lainnya'

# %% [markdown]
# # Additional Post Data Cleaning (Labelled)

# %%
'''
Project: Bangkit Capstone Project
Group: B21-CAP0194
Part: Additional Post Data - Data Cleaning
'''

# %%
#Import Additional Post Dataset (Labelled)
url_one = 'https://drive.google.com/file/d/19TrifGssrQn9AtTbW-AtBOMJgN65nCll/view?usp=sharing'
file_id_one = url_one.split('/')[-2]
csv_url_one = 'https://drive.google.com/uc?id=' + file_id_one
df = pd.read_csv(csv_url_one, encoding = "ISO-8859-1")
df.head()
# Out:
#                                                 text  label
# 0  Schwartz and Southern also constructed four se...  Siber
# 1  If you think Internet flirting andÿcybersexÿar...  Siber
# 2  If a relationship were strong in the first pla...  Siber
# 3  Then, of course, there'sÿcybersex, which mostl...  Siber
# 4  She says that it is a daily occurrence to be i...  Siber

# %%
df.shape
# Out:
# (1347, 2)

# %%
#Safe Clean (Cleaning the new line command before it get removed by the next regex)
df['text'] =  [re.sub(r"\\n", " ", str(j)) for j in df['text']]

#Cleaning the 'b', Retweet, Unicode (\\x08\,\\xef\,etc), Mentions, Hashtags, Links, and '&amp'.
df['text'] =  [re.sub(r"^b|RT|\\\\x[\w][\w]|\@[\w\_]*|\#[\w]*|http\S+|\&amp", " ", str(j)) for j in df['text']]

#Clean other non-alphabetic character
df['text'] =  [re.sub(r"[^a-zA-Z ]+", " ", str(j)) for j in df['text']]

#Clean extra space in the beginning, middle, and last of the sentence
df['text'] = df['text'].apply(lambda x: x.strip()).apply(lambda x: " ".join(x.split()))

#Adding space after slash
df['text'] =  [re.sub(r"\/", " ", str(j)) for j in df['text']]
df.head()
# Out:
#                                                 text  label
# 0  Schwartz and Southern also constructed four se...  Siber
# 1  If you think Internet flirting and cybersex ar...  Siber
# 2  If a relationship were strong in the first pla...  Siber
# 3  Then of course there s cybersex which mostly c...  Siber
# 4  She says that it is a daily occurrence to be i...  Siber

# %%
#Transform the text into lowercase
df['text'] = df['text'].str.lower()

# %%
#Drop any duplicate row
df.drop_duplicates(inplace=True)

# %%
#Fill up the empty cells
df['text'].replace('', np.nan, inplace=True)

# %%
#Drop empty cells
df.dropna(subset=['text'], inplace=True)

# %%
#Create Index
df['index'] = range(0, len(df.index), 1)

# %%
#Save DataFrame to CSV
df.to_csv("capstoneaddposttweetcleaned.csv", index=False, encoding='utf-8')

# %% [markdown]
# # Additional Laporan Data Cleaning (Labelled)

# %%
'''
Project: Bangkit Capstone Project
Group: B21-CAP0194
Part: Additional Laporan Data - Data Cleaning
'''

# %%
#Import Additional Laporan Dataset
url_one = 'https://drive.google.com/file/d/1NUCUCuKaL0CYq2gdNueUq2BrN4cU7NeJ/view?usp=sharing'
file_id_one = url_one.split('/')[-2]
csv_url_one = 'https://drive.google.com/uc?id=' + file_id_one
df = pd.read_csv(csv_url_one, encoding = "ISO-8859-1")
df.head()
# Out:
#                                                 text             label
# 0  Some people have become so dependent onÿpsychi...  Kekerasan Psikis
# 1  Franzen has always been fond of putting his ch...  Kekerasan Psikis
# 2        guilt and shame add to theirÿpsychicÿstate;  Kekerasan Psikis
# 3  It?s aÿpsychicÿspace in which you feel at once...  Kekerasan Psikis
# 4  Some were trampled in the rush and others surv...  Kekerasan Psikis

# %%
df.shape
# Out:
# (970, 2)

# %%
#Safe Clean (Cleaning the new line command before it get removed by the next regex)
df['text'] =  [re.sub(r"\\n", " ", str(j)) for j in df['text']]

#Cleaning the 'b', Retweet, Unicode (\\x08\,\\xef\,etc), Mentions, Hashtags, Links, and '&amp'.
df['text'] =  [re.sub(r"^b|RT|\\\\x[\w][\w]|\@[\w\_]*|\#[\w]*|http\S+|\&amp", " ", str(j)) for j in df['text']]

#Clean other non-alphabetic character
df['text'] =  [re.sub(r"[^a-zA-Z ]+", " ", str(j)) for j in df['text']]

#Clean extra space in the beginning, middle, and last of the sentence
df['text'] = df['text'].apply(lambda x: x.strip()).apply(lambda x: " ".join(x.split()))

#Adding space after slash
df['text'] =  [re.sub(r"\/", " ", str(j)) for j in df['text']]
df.head()
# Out:
#                                                 text             label
# 0  Some people have become so dependent on psychi...  Kekerasan Psikis
# 1  Franzen has always been fond of putting his ch...  Kekerasan Psikis
# 2         guilt and shame add to their psychic state  Kekerasan Psikis
# 3  It s a psychic space in which you feel at once...  Kekerasan Psikis
# 4  Some were trampled in the rush and others surv...  Kekerasan Psikis

# %%
#Transform the text into lowercase
df['text'] = df['text'].str.lower()

# %%
#Drop any duplicate row
df.drop_duplicates(inplace=True)

# %%
#Fill up the empty cells
df['text'].replace('', np.nan, inplace=True)

# %%
#Drop empty cells
df.dropna(subset=['text'], inplace=True)

# %%
#Create Index
df['index'] = range(0, len(df.index), 1)

# %%
#Save DataFrame to CSV
df.to_csv("capstoneaddlaporantweetcleaned.csv", index=False, encoding='utf-8')

# %% [markdown]
# After we cleaned the data, we only get **19455** tweets that we can use for training and testing.

# %% [markdown]
# # Data Labelling

# %%
#Import the Dataset
url = 'https://drive.google.com/file/d/1ifzdeuScEoALYpuatHPlPvn9vOYGfIIs/view?usp=sharing'
file_id = url.split('/')[-2]
csv_url = 'https://drive.google.com/uc?id=' + file_id
df = pd.read_csv(csv_url)
df.head()
# Out:
#                                                 text  index
# 0  the ironies of the movement are too painfully ...      0
# 1  women in kuwait have launched a social media c...      1
# 2  triger warning raising awareness of sexual ass...      2
# 3  charges brought against the guy that smacked m...      3
# 4  and the fourth presenter on th may is hannah b...      4

# %%
#Printing the shape/size of the dataframe
df.shape
# Out:
# (19455, 2)

# %%
#Initialize label column
df['label_laporan'] = ""
df['label_post'] = ""

# %%
# Report Labelling Process
# Note: Any unusual words that you find in this part of the code are used to label the dataset
for idx, line in enumerate(df['text']):
  
  #Label no. 1
  find_psychic = re.findall(r"fear|afraid|scare|self-confidence|loss|act|ability|helplessness|sense|suffering|psychic", line)
  if len(find_psychic) != 0 and df['label_laporan'][idx] == "":
    df['label_laporan'][idx] = "Kekerasan Psikis"
  #Label no. 2
  find_neglect = re.findall(r"neglect|reject|life|care|treatment|keep|raise|raising|control|under", line)
  if len(find_neglect) != 0 and df['label_laporan'][idx] == "":
    df['label_laporan'][idx] = "Penelantaran"
 
  #Label no. 3
  find_exploit = re.findall(r"force|pressure|work|service|job|slave|serf|oppression|suppression|extortion|exploitation|utilization|organ|transplant|kidnapping|trade|trafficking", line)
  if len(find_exploit) != 0 and df['label_laporan'][idx] == "":
    df['label_laporan'][idx] = "Eksploitasi"

  #Label no. 4
  find_expsex = re.findall(r"prostitution|porn|pornography|pornographic|pornographies|reproduction|commercial|show|off|nude|body|erotic", line)
  if len(find_expsex) != 0 and df['label_laporan'][idx] == "":
    df['label_laporan'][idx] = "Eksploitasi Seksual"

  #Label no. 5
  find_physical = re.findall(r"assault|violence|hurt|ill|wound|injury|sore|bleed|blood", line)
  if len(find_physical) != 0 and df['label_laporan'][idx] == "":
    df['label_laporan'][idx] = "Kekerasan Fisik"

  #Label no. 6
  find_sexual = re.findall(r"sexual|unwanted|force|forcing|household|home|house|housewifery|rape|raped|sex|threat|fuck|sleep|make love|obscene|lewd|dirty|vulgar|sexist|ass|butt|breast|genital", line)
  if len(find_sexual) != 0 and df['label_laporan'][idx] == "":
    df['label_laporan'][idx] = "Kekerasan Seksual"

  #Label no. 7
  if df['label_laporan'][idx] == "":
    df['label_laporan'][idx] = "Kekerasan Lainnya"
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Post Labelling Process
for idx, line in enumerate(df['text']):

  # Label 1 : Educational places
  find_educational = re.findall(r"teacher|classmate|school|university|college|headmaster|principal|preschool|academy|teach|professor|class|mate|research|education|educator|study|universities|bully|lecture|student|dorm|uniform|library|laboratory", line)
  if len(find_educational) != 0 and df['label_post'][idx] == "":
    df['label_post'][idx] = "Lokasi Pendidikan"

  # Label 2 : Work places
  find_workplace = re.findall(r"colleague|boss|job|pervert|work|workplace|ceo|partner|leader|manager|department|industry|interview|office|pantry|employee|business|client|staff|career|physical|verbal|company|desk|team|division|unwanted|cornering|chief|mentor|fire|locker|intern", line)
  if len(find_workplace) != 0 and df['label_post'][idx] == "":
    df['label_post'][idx] = "Lokasi Kerja"
  
  # Label 3 : Cyber
  find_cyber = re.findall(r"sexting|call|text|video|photo|picture|comment|cyber|porn|pornography|phone|app|camera|chat|message|image|malicious|virtual|online|webcam|cctv|post|email|hoax|media|website|article|instagram|twitter|snapchat|facebook|whatsapp|messenger|telegram|computer|ip address|record", line)
  if len(find_cyber) != 0 and df['label_post'][idx] == "":
    df['label_post'][idx] = "Siber"

  # Label 4 : Private places
  find_private = re.findall(r"private|home|friend|marital rape|abortion|family|boyfriend|ex|ex-boyfriend|stalking|stalker|raped|murder|smack|sleep|touch|sexual|kiss|date|obscene|attempt|sex|harassment|parent|husband|raping|dating|conversation|relationship|kick|attack|genital|married|housewives|masturbate|chest|jerk|neighbor|sodomy|personal|naked|nude|body|strip", line)
  if len(find_private) != 0 and df['label_post'][idx] == "":
    df['label_post'][idx] = "Lokasi Privat"
  
  # Label 5 : Public/community places
  find_public = re.findall(r"public|domestic|hospital|transport|community|spy|catcalling|catcall|rumor|ass|breast|butt|stranger|man|guy|exploitation|slave|hug|abuse|violence|gender|men|accuse|pervert|street|bad|society|violent|criminal|crime|steal|medical|grab|feminism|fenimist|prostitute|park|gun|rob|predator|toilet|kidnap|kidnapping|trade|trafficking|murder|cat|watch|cafe|restaurant|shaming|politic|store|train|station|pocket|customer|pedophile|driver|perv|gym", line)
  if len(find_public) != 0 and df['label_post'][idx] == "":
    df['label_post'][idx] = "Lokasi Publik"

  # Label 6 : Neutral (If the tweets doesn't fit the other 5 categories, the tweet will be labelled as 'neutral')
  if df['label_post'][idx] == "":
    df['label_post'][idx] = "Netral"
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#Counting the value in every labels
df['label_laporan'].value_counts()
# Out:
# Kekerasan Lainnya      9972
# Kekerasan Fisik        2284
# Kekerasan Seksual      2196
# Kekerasan Psikis       1649
# Penelantaran           1373
# Eksploitasi            1059
# Eksploitasi Seksual     922
# Name: label_laporan, dtype: int64

# %%
#Counting the value in every labels
df['label_post'].value_counts()
# Out:
# Netral               5500
# Lokasi Publik        4418
# Lokasi Privat        3643
# Siber                2753
# Lokasi Kerja         2224
# Lokasi Pendidikan     917
# Name: label_post, dtype: int64

# %%
# %matplotlib inline
my_tags = df['label_post']
plt.figure(figsize=(10,4))
df.label_post.value_counts().plot(kind='bar');

# %%
# %matplotlib inline
my_tags = df['label_laporan']
plt.figure(figsize=(10,4))
df.label_laporan.value_counts().plot(kind='bar');

# %%
#Save DataFrame to CSV
df.to_csv("capstoneinitialtweetlabelled.csv", index=False)

# %% [markdown]
# # Final Post Dataset

# %%
#Read Initial Dataset
df_initial = pd.read_csv("capstoneinitialtweetlabelled.csv")
df_initial.head()
# Out:
#                                                 text  ...         label_post
# 0  the ironies of the movement are too painfully ...  ...       Lokasi Kerja
# 1  women in kuwait have launched a social media c...  ...              Siber
# 2  triger warning raising awareness of sexual ass...  ...      Lokasi Privat
# 3  charges brought against the guy that smacked m...  ...      Lokasi Privat
# 4  and the fourth presenter on th may is hannah b...  ...  Lokasi Pendidikan
#
# [5 rows x 4 columns]

# %%
#Import Additional Post Dataset
url_post = 'https://drive.google.com/file/d/16-zEm0bhmMS6HZPfCrDhqJU2ZiixN-ex/view?usp=sharing'
file_id_post = url_post.split('/')[-2]
csv_url_post = 'https://drive.google.com/uc?id=' + file_id_post
df_post = pd.read_csv(csv_url_post)
df_post.head()
# Out:
#    index                                               text  label
# 0      0  schwartz and southern also constructed four se...  Siber
# 1      1  if you think internet flirting and cybersex ar...  Siber
# 2      2  if a relationship were strong in the first pla...  Siber
# 3      3  then of course there s cybersex which mostly c...  Siber
# 4      4  she says that it is a daily occurrence to be i...  Siber

# %%
#Adjust columns between two datasets
df_initial.rename(columns={'label_post': 'label'}, inplace = True)
df_initial.drop(columns=['index', 'label_laporan'], inplace=True)
df_post = df_post.drop(columns=['index'])

# %%
df_initial.head()
# Out:
#                                                 text              label
# 0  the ironies of the movement are too painfully ...       Lokasi Kerja
# 1  women in kuwait have launched a social media c...              Siber
# 2  triger warning raising awareness of sexual ass...      Lokasi Privat
# 3  charges brought against the guy that smacked m...      Lokasi Privat
# 4  and the fourth presenter on th may is hannah b...  Lokasi Pendidikan

# %%
df_post.head()
# Out:
#                                                 text  label
# 0  schwartz and southern also constructed four se...  Siber
# 1  if you think internet flirting and cybersex ar...  Siber
# 2  if a relationship were strong in the first pla...  Siber
# 3  then of course there s cybersex which mostly c...  Siber
# 4  she says that it is a daily occurrence to be i...  Siber

# %%
# Merging initial dataset with additional dataset
df_final_post = pd.concat([df_initial, df_post])

# %%
#Create Index
df_final_post['index'] = range(0, len(df_final_post.index), 1)

# %%
df_final_post['label'].value_counts()
# Out:
# Netral               5500
# Lokasi Publik        4418
# Lokasi Privat        3643
# Siber                2788
# Lokasi Kerja         2224
# Lokasi Pendidikan    2109
# Name: label, dtype: int64

# %%
df_final_post.shape
# Out:
# (20682, 3)

# %%
#Save DataFrame to CSV
df_final_post.to_csv("capstonetweetpostlabelled.csv", index=False)

# %% [markdown]
# # Final Report Dataset

# %%
#Read Initial Dataset
df_initial = pd.read_csv("capstoneinitialtweetlabelled.csv")
df_initial.head()
# Out:
#                                                 text  ...         label_post
# 0  the ironies of the movement are too painfully ...  ...       Lokasi Kerja
# 1  women in kuwait have launched a social media c...  ...              Siber
# 2  triger warning raising awareness of sexual ass...  ...      Lokasi Privat
# 3  charges brought against the guy that smacked m...  ...      Lokasi Privat
# 4  and the fourth presenter on th may is hannah b...  ...  Lokasi Pendidikan
#
# [5 rows x 4 columns]

# %%
#Import Additional Laporan Dataset
url_laporan = 'https://drive.google.com/file/d/162J0iMJKq4IuDuo9fnXsmdvMpBKdCXVj/view?usp=sharing'
file_id_laporan = url_laporan.split('/')[-2]
csv_url_laporan = 'https://drive.google.com/uc?id=' + file_id_laporan
df_laporan = pd.read_csv(csv_url_laporan)
df_laporan.head()
# Out:
#    index                                               text             label
# 0      0  some people have become so dependent on psychi...  Kekerasan Psikis
# 1      1  franzen has always been fond of putting his ch...  Kekerasan Psikis
# 2      2         guilt and shame add to their psychic state  Kekerasan Psikis
# 3      3  it s a psychic space in which you feel at once...  Kekerasan Psikis
# 4      4  some were trampled in the rush and others surv...  Kekerasan Psikis

# %%
#Adjust columns between two datasets
df_initial.rename(columns={'label_laporan': 'label'}, inplace = True)
df_initial.drop(columns=['index', 'label_post'], inplace=True)
df_laporan = df_laporan.drop(columns=['index'])

# %%
df_initial.head()
# Out:
#                                                 text              label
# 0  the ironies of the movement are too painfully ...   Kekerasan Psikis
# 1  women in kuwait have launched a social media c...   Kekerasan Psikis
# 2  triger warning raising awareness of sexual ass...       Penelantaran
# 3  charges brought against the guy that smacked m...    Kekerasan Fisik
# 4  and the fourth presenter on th may is hannah b...  Kekerasan Lainnya

# %%
df_laporan.head()
# Out:
#                                                 text             label
# 0  some people have become so dependent on psychi...  Kekerasan Psikis
# 1  franzen has always been fond of putting his ch...  Kekerasan Psikis
# 2         guilt and shame add to their psychic state  Kekerasan Psikis
# 3  it s a psychic space in which you feel at once...  Kekerasan Psikis
# 4  some were trampled in the rush and others surv...  Kekerasan Psikis

# %%
# Merging initial dataset with additional dataset
df_final_laporan = pd.concat([df_initial, df_laporan])

# %%
#Create Index
df_final_laporan['index'] = range(0, len(df_final_laporan.index), 1)

# %%
df_final_laporan['label'].value_counts()
# Out:
# Kekerasan Lainnya      9972
# Kekerasan Fisik        2284
# Kekerasan Seksual      2196
# Kekerasan Psikis       2090
# Eksploitasi Seksual    1445
# Penelantaran           1373
# Eksploitasi            1059
# Name: label, dtype: int64

# %%
df_final_laporan.shape
# Out:
# (20419, 3)

# %%
#Save DataFrame to CSV
df_final_laporan.to_csv("capstonetweetlaporanlabelled.csv", index=False)

# %% [markdown]
# # Conclusion

# %% [markdown]
# We can conclude that:
# 1. Average tweets in #MeToo movement per week is 5866 tweets.
# 2. We got 58600 tweets within 7 periods time.
# 2. We added additional datasets manually with related class for each classification.
#
#
# *   Post classification : 1227 tweets
# *   Report classification : 964 tweets
#
#
# 2. Total dataset for each classification.
#
#
# *   Post classification dataset total : 20682 tweets
# *   Report classification dataset total : 20419 tweets
#
# 3. From the WordCloud, we can see that #MeToo is a movement aimed at woman. This movement contains many stories of experiences of sexual violence or sexual harassment experienced by woman.
# 4. There are words about sexual violence and harassment such as 'sexual assault', 'accused', 'raped', 'rape', 'sexual abuse', 'rapist', 'fuck', 'feminist', 'abuser', 'sexual harassment', etc.
